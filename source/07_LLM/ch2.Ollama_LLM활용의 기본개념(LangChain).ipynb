# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
table.dataframe{font-size:22px;}
table td, th{font-size:16px;}
table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
# table.dataframe{font-size:22px;}
# table td, th{font-size:16px;}
# table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch2. Ollama_LLM활용의 기본개념(LangChain)</font>**
#
# # 1. LLM을 활용하여 답변 생성하기
# ## 1) Ollama를 이용한 로컬 LLM이용
# - 성능은 GPT(open ai API), Claude같은 모델보단 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ## ollama.com 설치 -> 모델 pull
# - cmd창에서 ollama pull deepseek-r1:1.5b

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke('What is the capital of France?')
result # AIMessage
# content : 실제답변
# response_metadata
# Out:
# AIMessage(content='\n\nThe capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-10T07:56:03.3206819Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4446664700, 'load_duration': 3931480900, 'prompt_eval_count': 10, 'prompt_eval_duration': 111164000, 'eval_count': 12, 'eval_duration': 391676000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--01a08a50-fe11-7b91-b640-789543d9b0d6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %%
result.response_metadata
# Out:
# {'model': 'deepseek-r1:1.5b',
#  'created_at': '2026-09-10T07:56:03.3206819Z',
#  'done': True,
#  'done_reason': 'stop',
#  'total_duration': 4446664700,
#  'load_duration': 3931480900,
#  'prompt_eval_count': 10,
#  'prompt_eval_duration': 111164000,
#  'eval_count': 12,
#  'eval_duration': 391676000,
#  'logprobs': None,
#  'model_name': 'deepseek-r1:1.5b',
#  'model_provider': 'ollama'}

# %%
print(result.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# ### 모델 pull
# - ollama pull llama3.2:1b
# - ollama 모델은 공식적으로 한글지원이 안됨(llama3.1:405b 한글지원가능->llama3.2:3b한글일부지원
# - exaone 모델은 공식적으로 한글지원 : ollama run exaone3.5:2.4b
#
# - 모델 저장경로 : C:/Users/내컴퓨터이름/.ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke('What is the capital of Korea?')
result
# Out:
# AIMessage(content='The capital of South Korea is Seoul. The Demilitarized Zone (DMZ) between North and South Korea is also located in Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-10T08:31:18.5919779Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3598130700, 'load_duration': 2065235300, 'prompt_eval_count': 32, 'prompt_eval_duration': 365970000, 'eval_count': 30, 'eval_duration': 1150107000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08a71-482f-7c40-8ee6-02e3372a8073-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 30, 'total_tokens': 62})

# %%
result.content
# Out:
# 'The capital of South Korea is Seoul. The Demilitarized Zone (DMZ) between North and South Korea is also located in Seoul.'

# %%
result = llm.invoke('한국 수도는 어디?')
result.content
# Out:
# '한국의 수도는 Seoul입니다.'

# %% [markdown]
# ### 2) openai 모델활용
# - pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano", api_key)
result = llm.invoke('What is the capital of Korea')
# result = llm.invoke('한글의 수도')
result.content
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 llm = ChatOpenAI(model="gpt-4.1-nano")
#       3 result = llm.invoke('What is the capital of Korea')
#       4 # result = llm.invoke('한글의 수도')
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_openai\chat_models\base.py:1465, in BaseChatOpenAI.validate_environment(self)
#    1451         self.http_async_client = _build_proxied_async_httpx_client(
#    1452             proxy=self.openai_proxy,
#    1453             verify=global_ssl_context,
#    1454             socket_options=resolved_socket_options,
#    1455         )
#    1456     async_specific = {
#    1457         "http_client": self.http_async_client
#    1458         or _get_default_async_httpx_client(
#    (...)
#    1463         "api_key": async_api_key_value,
#    1464     }
# -> 1465     self.root_async_client = openai.AsyncOpenAI(
#    1466         **client_params,
#    1467         **async_specific,  # type: ignore[arg-type]
#    1468     )
#    1469     self.async_client = self.root_async_client.chat.completions
#    1470 return self
#
# File ~\anaconda3\envs\llm\lib\site-packages\openai\_client.py:1019, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, data_residency, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#    1009 self.admin_api_key = admin_api_key if provider_runtime is None else None
#    1011 if (
#    1012     provider_runtime is None
#    1013     and _enforce_credentials
#    (...)
#    1017     and self.admin_api_key is None
#    1018 ):
# -> 1019     raise OpenAIError(
#    1020         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#    1021     )
#    1023 if organization is None and provider_runtime is None:
#    1024     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
