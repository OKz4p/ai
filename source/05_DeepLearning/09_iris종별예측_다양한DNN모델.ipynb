# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
import numpy as np
import pandas as pd
import seaborn as sns # iris(데이터프레임)가져오기
from sklearn import datasets # iris(X와 y가 분리되서 numpy) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨 인코더
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt

# %% [markdown]
# ```
# - 데이터셋 생성 및 전처리
#     X, y(라벨인코딩)분리 -> train_test_split 분리(8:2)
# - 모델 구성(입력4, 출력3, layer : 4->64->128->50->30->3)
# - 학습과정 설정 (loss='sparse_categorical_crossentropy')
# - 학습
# - 모델평가(가장 최선의 모델을 get)
# - 모델 사용(저장/예측)
# ```
# # 1. 기본적인 DNN
# ## 1. 데이터 셋 생성 및 전처리

# %%
# iris가져오기 방법 1
iris = sns.load_dataset('iris')
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris_X = iris.iloc[:, :-1].values
labelEncoder = LabelEncoder()
iris_y = labelEncoder.fit_transform(iris.iloc[:, -1]) # 0:setosa/1:versicolor/2:virginica
iris_X.shape, iris_y.shape
# Out:
# ((150, 4), (150,))

# %%
# iris가져오기 방법 2
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
print(iris.target_names)
iris_X.shape, iris_y.shape
# Out:
# ['setosa' 'versicolor' 'virginica']
# ((150, 4), (150,))

# %%
# 학습셋과 테스트셋 분리
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.2,
                                                   stratify=iris_y # 층화추출
                                                   )
np.c_[pd.Series(iris_y).value_counts(normalize=True),
      pd.Series(train_y).value_counts(normalize=True),
      pd.Series(test_y).value_counts(normalize=True)]
# Out:
# array([[0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.33333333, 0.33333333]])

# %%
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %% [markdown]
# ## 2. 모델 구성 및 학습
# - 4->64->128->50->30->3
# - He초기화, 다양한 activation, 배치정규화, L2정규화, Dropout

# %%
model = Sequential([
    Input(4),
    Dense(units=64, activation='relu'),
    Dense(units=128, activation='elu'),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax'),
], 'sequential')
# model = Sequential(name='sequential')
# model.add(Input(4))
# model.add(Dense(units=64, activation='relu'))
# model.add(Dense(units=128, activation='relu'))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 50)                6450
#
#  dense_3 (Dense)             (None, 30)                1530
#
#  dense_4 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
earlystopping = EarlyStopping(patience=50) # monitor='val_loss'가 기본값
model_save_folder = 'model/'
import os
if not os.path.exists(model_save_folder):
    os.mkdir(model_save_folder)
file = model_save_folder + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
checkpoint = ModelCheckpoint(monitor='val_loss',
                            filepath=file, # 모델 저장 파일
                            save_best_only=True, # 모니터 지표가 개선된 경우만 모델 저장
                            verbose=1) # 저장 여부 로그 출력
hist = model.fit(train_X, train_y,
                epochs=200,
                validation_split=0.1,
                callbacks=[earlystopping, checkpoint],
                verbose=1)
# Out:
# Epoch 1/200
# 1/4 [======>.......................] - ETA: 2s - loss: 1.2957 - accuracy: 0.4375
# Epoch 1: val_loss improved from inf to 1.26996, saving model to model\iris-001-loss1.2700-acc0.0000.h5
# 4/4 [==============================] - 1s 139ms/step - loss: 1.2234 - accuracy: 0.3148 - val_loss: 1.2700 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 1/4 [======>.......................] - ETA: 0s - loss: 1.0249 - accuracy: 0.3438
# Epoch 2: val_loss improved from 1.26996 to 0.72805, saving model to model\iris-002-loss0.7280-acc1.0000.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.9613 - accuracy: 0.4537 - val_loss: 0.7280 - val_accuracy: 1.0000
# Epoch 3/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8548 - accuracy: 0.6250
# Epoch 3: val_loss improved from 0.72805 to 0.61745, saving model to model\iris-003-loss0.6174-acc0.7500.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.8479 - accuracy: 0.6296 - val_loss: 0.6174 - val_accuracy: 0.7500
# Epoch 4/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7411 - accuracy: 0.8125
# Epoch 4: val_loss improved from 0.61745 to 0.50650, saving model to model\iris-004-loss0.5065-acc1.0000.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.7197 - accuracy: 0.6574 - val_loss: 0.5065 - val_accuracy: 1.0000
# Epoch 5/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6537 - accuracy: 0.6875
# Epoch 5: val_loss improved from 0.50650 to 0.43078, saving model to model\iris-005-loss0.4308-acc1.0000.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6529 - accuracy: 0.6296 - val_loss: 0.4308 - val_accuracy: 1.0000
# Epoch 6/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5891 - accuracy: 0.9375
# Epoch 6: val_loss did not improve from 0.43078
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5704 - accuracy: 0.9259 - val_loss: 0.4453 - val_accuracy: 0.6667
# Epoch 7/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4473 - accuracy: 0.8125
# Epoch 7: val_loss improved from 0.43078 to 0.40246, saving model to model\iris-007-loss0.4025-acc0.6667.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5399 - accuracy: 0.6852 - val_loss: 0.4025 - val_accuracy: 0.6667
# Epoch 8/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4855 - accuracy: 0.7188
# Epoch 8: val_loss improved from 0.40246 to 0.24928, saving model to model\iris-008-loss0.2493-acc1.0000.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4747 - accuracy: 0.8056 - val_loss: 0.2493 - val_accuracy: 1.0000
# Epoch 9/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4467 - accuracy: 0.8438
# Epoch 9: val_loss improved from 0.24928 to 0.20766, saving model to model\iris-009-loss0.2077-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4477 - accuracy: 0.7685 - val_loss: 0.2077 - val_accuracy: 1.0000
# Epoch 10/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3919 - accuracy: 0.8125
# Epoch 10: val_loss did not improve from 0.20766
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4095 - accuracy: 0.8889 - val_loss: 0.3199 - val_accuracy: 0.7500
# Epoch 11/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4152 - accuracy: 0.8438
# Epoch 11: val_loss did not improve from 0.20766
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4044 - accuracy: 0.7870 - val_loss: 0.3006 - val_accuracy: 0.8333
# Epoch 12/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3618 - accuracy: 0.9688
# Epoch 12: val_loss improved from 0.20766 to 0.18299, saving model to model\iris-012-loss0.1830-acc1.0000.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3590 - accuracy: 0.9444 - val_loss: 0.1830 - val_accuracy: 1.0000
# Epoch 13/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2799 - accuracy: 0.9688
# Epoch 13: val_loss did not improve from 0.18299
# 4/4 [==============================] - 0s 22ms/step - loss: 0.3280 - accuracy: 0.9537 - val_loss: 0.2314 - val_accuracy: 0.9167
# Epoch 14/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3027 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.18299
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3390 - accuracy: 0.9074 - val_loss: 0.2237 - val_accuracy: 0.9167
# Epoch 15/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2741 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.18299 to 0.09856, saving model to model\iris-015-loss0.0986-acc1.0000.h5
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3334 - accuracy: 0.8796 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 16/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3288 - accuracy: 0.8438
# Epoch 16: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2843 - accuracy: 0.9074 - val_loss: 0.3023 - val_accuracy: 0.7500
# Epoch 17/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3084 - accuracy: 0.8438
# Epoch 17: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2803 - accuracy: 0.9167 - val_loss: 0.1673 - val_accuracy: 1.0000
# Epoch 18/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2080 - accuracy: 0.9688
# Epoch 18: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2365 - accuracy: 0.9630 - val_loss: 0.1296 - val_accuracy: 1.0000
# Epoch 19/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2362 - accuracy: 0.9688
# Epoch 19: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2229 - accuracy: 0.9722 - val_loss: 0.2036 - val_accuracy: 0.8333
# Epoch 20/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1869 - accuracy: 0.9688
# Epoch 20: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2027 - accuracy: 0.9630 - val_loss: 0.1132 - val_accuracy: 1.0000
# Epoch 21/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2392 - accuracy: 0.9375
# Epoch 21: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1996 - accuracy: 0.9630 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 22/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2194 - accuracy: 0.9375
# Epoch 22: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1779 - accuracy: 0.9722 - val_loss: 0.1843 - val_accuracy: 0.8333
# Epoch 23/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1729 - accuracy: 0.9688
# Epoch 23: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1702 - accuracy: 0.9722 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 24/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1326 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.09856
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1555 - accuracy: 0.9722 - val_loss: 0.1535 - val_accuracy: 0.9167
# Epoch 25/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1795 - accuracy: 0.9688
# Epoch 25: val_loss improved from 0.09856 to 0.09665, saving model to model\iris-025-loss0.0967-acc1.0000.h5
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1471 - accuracy: 0.9722 - val_loss: 0.0967 - val_accuracy: 1.0000
# Epoch 26/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1658 - accuracy: 0.9688
# Epoch 26: val_loss improved from 0.09665 to 0.08597, saving model to model\iris-026-loss0.0860-acc1.0000.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1501 - accuracy: 0.9722 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 27/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1098 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.08597
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1332 - accuracy: 0.9630 - val_loss: 0.1762 - val_accuracy: 0.8333
# Epoch 28/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1355 - accuracy: 0.9688
# Epoch 28: val_loss improved from 0.08597 to 0.06985, saving model to model\iris-028-loss0.0698-acc1.0000.h5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1395 - accuracy: 0.9630 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 29/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1571 - accuracy: 0.9688
# Epoch 29: val_loss did not improve from 0.06985
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1181 - accuracy: 0.9722 - val_loss: 0.1721 - val_accuracy: 0.8333
# Epoch 30/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1050 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.06985
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1220 - accuracy: 0.9444 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 31/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1008 - accuracy: 0.9688
# Epoch 31: val_loss improved from 0.06985 to 0.06541, saving model to model\iris-031-loss0.0654-acc1.0000.h5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1158 - accuracy: 0.9630 - val_loss: 0.0654 - val_accuracy: 1.0000
# Epoch 32/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0674 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.06541
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1186 - accuracy: 0.9537 - val_loss: 0.1374 - val_accuracy: 0.9167
# Epoch 33/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1434 - accuracy: 0.9688
# Epoch 33: val_loss improved from 0.06541 to 0.05777, saving model to model\iris-033-loss0.0578-acc1.0000.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1189 - accuracy: 0.9815 - val_loss: 0.0578 - val_accuracy: 1.0000
# Epoch 34/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1707 - accuracy: 0.9375
# Epoch 34: val_loss did not improve from 0.05777
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1179 - accuracy: 0.9537 - val_loss: 0.1415 - val_accuracy: 0.9167
# Epoch 35/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1018 - accuracy: 0.9688
# Epoch 35: val_loss improved from 0.05777 to 0.04340, saving model to model\iris-035-loss0.0434-acc1.0000.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0934 - accuracy: 0.9722 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 36/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0664 - accuracy: 0.9688
# Epoch 36: val_loss did not improve from 0.04340
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0978 - accuracy: 0.9722 - val_loss: 0.1428 - val_accuracy: 0.9167
# Epoch 37/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1105 - accuracy: 0.9688
# Epoch 37: val_loss did not improve from 0.04340
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1176 - accuracy: 0.9444 - val_loss: 0.1386 - val_accuracy: 0.9167
# Epoch 38/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1546 - accuracy: 0.9375
# Epoch 38: val_loss improved from 0.04340 to 0.03071, saving model to model\iris-038-loss0.0307-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0866 - accuracy: 0.9722 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 39/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1652 - accuracy: 0.9688
# Epoch 39: val_loss did not improve from 0.03071
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1050 - accuracy: 0.9722 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 40/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0538 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.03071
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0902 - accuracy: 0.9630 - val_loss: 0.1229 - val_accuracy: 0.9167
# Epoch 41/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1300 - accuracy: 0.9688
# Epoch 41: val_loss did not improve from 0.03071
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0811 - accuracy: 0.9815 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 42/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0458 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.03071
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0887 - accuracy: 0.9722 - val_loss: 0.0855 - val_accuracy: 1.0000
# Epoch 43/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1062 - accuracy: 0.9688
# Epoch 43: val_loss did not improve from 0.03071
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1012 - accuracy: 0.9630 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 44/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1176 - accuracy: 0.9688
# Epoch 44: val_loss improved from 0.03071 to 0.01355, saving model to model\iris-044-loss0.0135-acc1.0000.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0958 - accuracy: 0.9722 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 45/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2239 - accuracy: 0.9375
# Epoch 45: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1102 - accuracy: 0.9722 - val_loss: 0.1489 - val_accuracy: 0.8333
# Epoch 46/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0712 - accuracy: 0.9688
# Epoch 46: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0987 - accuracy: 0.9444 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 47/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1279 - accuracy: 0.9375
# Epoch 47: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0828 - accuracy: 0.9630 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 48/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0393 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0921 - accuracy: 0.9722 - val_loss: 0.1300 - val_accuracy: 0.9167
# Epoch 49/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0588 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1176 - accuracy: 0.9537 - val_loss: 0.2095 - val_accuracy: 0.8333
# Epoch 50/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1271 - accuracy: 0.9375
# Epoch 50: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0962 - accuracy: 0.9722 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 51/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2316 - accuracy: 0.9062
# Epoch 51: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0981 - accuracy: 0.9630 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 52/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0405 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0693 - accuracy: 0.9815 - val_loss: 0.1401 - val_accuracy: 0.9167
# Epoch 53/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0357 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0804 - accuracy: 0.9630 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 54/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1285 - accuracy: 0.9375
# Epoch 54: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0741 - accuracy: 0.9722 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 55/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1243 - accuracy: 0.9688
# Epoch 55: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0781 - accuracy: 0.9815 - val_loss: 0.0397 - val_accuracy: 1.0000
# Epoch 56/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0335 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0700 - accuracy: 0.9815 - val_loss: 0.1595 - val_accuracy: 0.8333
# Epoch 57/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1677 - accuracy: 0.8750
# Epoch 57: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0742 - accuracy: 0.9630 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 58/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1160 - accuracy: 0.9688
# Epoch 58: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0754 - accuracy: 0.9722 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 59/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0611 - accuracy: 0.9688
# Epoch 59: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0722 - accuracy: 0.9722 - val_loss: 0.1268 - val_accuracy: 0.9167
# Epoch 60/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1451 - accuracy: 0.9062
# Epoch 60: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0751 - accuracy: 0.9630 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 61/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0503 - accuracy: 0.9688
# Epoch 61: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0661 - accuracy: 0.9815 - val_loss: 0.0473 - val_accuracy: 1.0000
# Epoch 62/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0510 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0671 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 63/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0342 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.01355
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0850 - accuracy: 0.9537 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 64/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1354 - accuracy: 0.9375
# Epoch 64: val_loss improved from 0.01355 to 0.01248, saving model to model\iris-064-loss0.0125-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0683 - accuracy: 0.9722 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 65/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2204 - accuracy: 0.9062
# Epoch 65: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0904 - accuracy: 0.9630 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 66/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0660 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0653 - accuracy: 0.9815 - val_loss: 0.2545 - val_accuracy: 0.8333
# Epoch 67/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1196 - accuracy: 0.9352 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 68/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0312 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0966 - accuracy: 0.9722 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 69/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0426 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0803 - accuracy: 0.9630 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 70/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0529 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0665 - accuracy: 0.9815 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 71/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1081 - accuracy: 0.9688
# Epoch 71: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0625 - accuracy: 0.9815 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 72/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0356 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0636 - accuracy: 0.9815 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 73/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0394 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0631 - accuracy: 0.9815 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 74/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0253 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0633 - accuracy: 0.9815 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 75/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1221 - accuracy: 0.9375
# Epoch 75: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0603 - accuracy: 0.9815 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 76/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0068 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0706 - accuracy: 0.9722 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 77/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0422 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0614 - accuracy: 0.9815 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 78/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0933 - accuracy: 0.9688
# Epoch 78: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0734 - accuracy: 0.9722 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 79/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0730 - accuracy: 0.9815 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 80/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0136 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0695 - accuracy: 0.9722 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 81/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0957 - accuracy: 0.9688
# Epoch 81: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0662 - accuracy: 0.9815 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 82/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0308 - accuracy: 1.0000
# Epoch 82: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0672 - accuracy: 0.9722 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 83/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0417 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0626 - accuracy: 0.9815 - val_loss: 0.1504 - val_accuracy: 0.8333
# Epoch 84/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1275 - accuracy: 0.9375
# Epoch 84: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0816 - accuracy: 0.9537 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 85/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0211 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0589 - accuracy: 0.9815 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 86/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1056 - accuracy: 0.9688
# Epoch 86: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0666 - accuracy: 0.9815 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 87/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1368 - accuracy: 0.9688
# Epoch 87: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0627 - accuracy: 0.9907 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 88/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0539 - accuracy: 0.9688
# Epoch 88: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0649 - accuracy: 0.9722 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 89/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0169 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0688 - accuracy: 0.9722 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 90/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0131 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0605 - accuracy: 0.9815 - val_loss: 0.1327 - val_accuracy: 0.9167
# Epoch 91/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0902 - accuracy: 0.9688
# Epoch 91: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0685 - accuracy: 0.9815 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 92/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0345 - accuracy: 0.9688
# Epoch 92: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0626 - accuracy: 0.9815 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 93/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0322 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0590 - accuracy: 0.9815 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 94/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1328 - accuracy: 0.9375
# Epoch 94: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 0.0518 - val_accuracy: 1.0000
# Epoch 95/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0412 - accuracy: 1.0000
# Epoch 95: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0597 - accuracy: 0.9815 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 96/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0361 - accuracy: 0.9688
# Epoch 96: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 0.0961 - val_accuracy: 1.0000
# Epoch 97/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0624 - accuracy: 0.9688
# Epoch 97: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0672 - accuracy: 0.9815 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 98/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0201 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0595 - accuracy: 0.9815 - val_loss: 0.0807 - val_accuracy: 1.0000
# Epoch 99/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0420 - accuracy: 1.0000
# Epoch 99: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0619 - accuracy: 0.9722 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 100/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 101/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 101: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0689 - accuracy: 0.9722 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 102/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1029 - accuracy: 0.9688
# Epoch 102: val_loss did not improve from 0.01248
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1281 - accuracy: 0.9537 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 103/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1281 - accuracy: 0.9688
# Epoch 103: val_loss improved from 0.01248 to 0.00163, saving model to model\iris-103-loss0.0016-acc1.0000.h5
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0933 - accuracy: 0.9630 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 104/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3635 - accuracy: 0.9062
# Epoch 104: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1405 - accuracy: 0.9630 - val_loss: 0.1863 - val_accuracy: 0.8333
# Epoch 105/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0691 - accuracy: 0.9688
# Epoch 105: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0754 - accuracy: 0.9630 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 106/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0532 - accuracy: 0.9688
# Epoch 106: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0750 - accuracy: 0.9722 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 107/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1416 - accuracy: 0.9688
# Epoch 107: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0763 - accuracy: 0.9722 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 108/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1045 - accuracy: 0.9688
# Epoch 108: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0782 - accuracy: 0.9722 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 109/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0365 - accuracy: 1.0000
# Epoch 109: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0600 - accuracy: 0.9815 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 110/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0364 - accuracy: 0.9688
# Epoch 110: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0620 - accuracy: 0.9815 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 111/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0258 - accuracy: 1.0000
# Epoch 111: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0640 - accuracy: 0.9815 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 112/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0429 - accuracy: 0.9688
# Epoch 112: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0555 - accuracy: 0.9815 - val_loss: 0.1145 - val_accuracy: 1.0000
# Epoch 113/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0460 - accuracy: 0.9688
# Epoch 113: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0644 - accuracy: 0.9722 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 114/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0612 - accuracy: 0.9688
# Epoch 114: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0599 - accuracy: 0.9815 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 115/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0691 - accuracy: 0.9375
# Epoch 115: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0643 - accuracy: 0.9722 - val_loss: 0.0616 - val_accuracy: 1.0000
# Epoch 116/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0118 - accuracy: 1.0000
# Epoch 116: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0565 - accuracy: 0.9815 - val_loss: 0.0776 - val_accuracy: 1.0000
# Epoch 117/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0491 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0639 - accuracy: 0.9722 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 118/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1348 - accuracy: 0.9375
# Epoch 118: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0734 - accuracy: 0.9630 - val_loss: 0.1587 - val_accuracy: 0.8333
# Epoch 119/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0743 - accuracy: 0.9375
# Epoch 119: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0670 - accuracy: 0.9630 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 120/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1084 - accuracy: 0.9688
# Epoch 120: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0644 - accuracy: 0.9722 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 121/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1057 - accuracy: 0.9688
# Epoch 121: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0752 - accuracy: 0.9630 - val_loss: 0.1928 - val_accuracy: 0.8333
# Epoch 122/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0753 - accuracy: 0.9688
# Epoch 122: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0705 - accuracy: 0.9722 - val_loss: 0.0283 - val_accuracy: 1.0000
# Epoch 123/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 123: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0738 - accuracy: 0.9722 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 124/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0447 - accuracy: 0.9688
# Epoch 124: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.1399 - val_accuracy: 0.8333
# Epoch 125/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0950 - accuracy: 0.9375
# Epoch 125: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0684 - accuracy: 0.9722 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 126/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0393 - accuracy: 1.0000
# Epoch 126: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0581 - accuracy: 0.9907 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 127/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1023 - accuracy: 0.9688
# Epoch 127: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 128/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0329 - accuracy: 1.0000
# Epoch 128: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0543 - accuracy: 0.9815 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 129/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0479 - accuracy: 0.9688
# Epoch 129: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0594 - accuracy: 0.9722 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 130/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0269 - accuracy: 0.9688
# Epoch 130: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0599 - accuracy: 0.9722 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 131/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0502 - accuracy: 1.0000
# Epoch 131: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0515 - accuracy: 0.9907 - val_loss: 0.1242 - val_accuracy: 0.9167
# Epoch 132/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 132: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 133/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 133: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0541 - accuracy: 0.9815 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 134/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0544 - accuracy: 0.9688
# Epoch 134: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 135/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0288 - accuracy: 1.0000
# Epoch 135: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0502 - accuracy: 0.9815 - val_loss: 0.1420 - val_accuracy: 0.8333
# Epoch 136/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 136: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0990 - accuracy: 0.9444 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 137/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0509 - accuracy: 0.9688
# Epoch 137: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1187 - accuracy: 0.9630 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 138/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1712 - accuracy: 0.9688
# Epoch 138: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0715 - accuracy: 0.9815 - val_loss: 0.2300 - val_accuracy: 0.8333
# Epoch 139/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0753 - accuracy: 0.9375
# Epoch 139: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1262 - accuracy: 0.9352 - val_loss: 0.0807 - val_accuracy: 1.0000
# Epoch 140/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 140: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0788 - accuracy: 0.9722 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 141/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0228 - accuracy: 1.0000
# Epoch 141: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1120 - accuracy: 0.9630 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 142/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0286 - accuracy: 1.0000
# Epoch 142: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0601 - accuracy: 0.9722 - val_loss: 0.1619 - val_accuracy: 0.8333
# Epoch 143/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0550 - accuracy: 0.9688
# Epoch 143: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0729 - accuracy: 0.9630 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 144/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1030 - accuracy: 0.9688
# Epoch 144: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0570 - accuracy: 0.9722 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 145/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0953 - accuracy: 0.9375
# Epoch 145: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0625 - accuracy: 0.9722 - val_loss: 0.0640 - val_accuracy: 1.0000
# Epoch 146/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0304 - accuracy: 1.0000
# Epoch 146: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0715 - accuracy: 0.9722 - val_loss: 0.1290 - val_accuracy: 0.9167
# Epoch 147/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0770 - accuracy: 0.9688
# Epoch 147: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0620 - accuracy: 0.9722 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 148/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1630 - accuracy: 0.9375
# Epoch 148: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0670 - accuracy: 0.9722 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 149/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0191 - accuracy: 1.0000
# Epoch 149: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0561 - accuracy: 0.9815 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 150/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0810 - accuracy: 0.9688
# Epoch 150: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0648 - accuracy: 0.9722 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 151/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 151: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0602 - accuracy: 0.9815 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 152/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0367 - accuracy: 1.0000
# Epoch 152: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0501 - accuracy: 0.9907 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 153/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0253 - accuracy: 1.0000
# Epoch 153: val_loss did not improve from 0.00163
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0618 - accuracy: 0.9722 - val_loss: 0.0901 - val_accuracy: 1.0000
# CPU times: total: 12.6 s
# Wall time: 10.8 s

# %% [markdown]
# ## 3. 모델 평가

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss, acc = model.evaluate(test_X, test_y)
print(loss, acc)
# Out:
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0247 - accuracy: 1.0000
# 0.02468007057905197 1.0

# %%
# 저장된 모델중 최선 모델
model1 = load_model('model/iris-103-loss0.0016-acc1.0000.h5')
loss1, acc1 = model1.evaluate(test_X, test_y)
print(loss1, acc1)
# Out:
# 1/1 [==============================] - 0s 177ms/step - loss: 0.2068 - accuracy: 0.9333
# 0.2068471908569336 0.9333333373069763

# %% [markdown]
# # 2. sklearn이용
# - 4->64->128->50->30->3

# %%
from sklearn.neural_network import MLPClassifier  # multi-layer perceptron
# 1. 데이터
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %%
# 2. 모델 생성
model = MLPClassifier(hidden_layer_sizes=(64, 128, 50, 30),
                     activation='relu',
                     solver='adam', # 옵티마이저
                     batch_size=40, # 학습시 batch_size
                     early_stopping=True, # 조기 종료 활성화,
                     n_iter_no_change=50, # earlystopping의 patience역할
                     validation_fraction=0.1, # 검증셋 비율
                     max_iter=200, 
                     warm_start=False, # True일 경우 이전학습에 이어서 학습
                     )

# %%
# 3. 모델 학습
model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True,
#               hidden_layer_sizes=(64, 128, 50, 30), n_iter_no_change=50)

# %%
# 4. 모델 평가
model.score(test_X, test_y)
# Out:
# 0.9666666666666667

# %%
# 5. 교차표(혼동행렬)
# 실제값 : test_y
y_hat = model.predict(test_X)
pd.crosstab(test_y, y_hat, rownames=['real'], colnames=['predict'])
# Out:
# predict   0  1   2
# real
# 0        10  0   0
# 1         0  9   1
# 2         0  0  10

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_y, y_hat)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  0, 10]], dtype=int64)

# %% [markdown]
# # 3. 클래스를 생성하여 모델 생성함수 사용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', output_dim=3, optimizer='adam'):
        # 모델 구성
        model = Sequential(layers=[
            Input(input_dim),
            Dense(units=50, activation=activation),
            Dense(units=30, activation=activation),
            Dense(units=output_dim, activation='softmax')
        ], name='sequential')
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        # 모델 return
        return model

# %%
# %%time
# 1. 데이터
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# 2. 모델
model = DNNClassifier.build(input_dim=4, activation='relu', output_dim=3, optimizer='adam')
# 3. 모델 학습
hist = model.fit(train_X, train_y,
                epochs=50, 
                validation_split=0.1, 
                verbose=0)
# Out:
# (120, 4) (120,) (30, 4) (30,)
# CPU times: total: 3.48 s
# Wall time: 3.16 s

# %%
# 모델 평가
loss, accuracy = model.evaluate(test_X, test_y, verbose=0)
print(f'정확도 : {accuracy*100}%')
# Out:
# 정확도 : 100.0%

# %% [markdown]
# # 4. 함수형 API
# - 병렬처리, Residual block

# %%
# 기존 model 스타일1
model = Sequential(layers=[
    Input(shape=(4,)),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax'),
])
# 기존 model 스타일2
model = Sequential()
model.add(Input(shape=(4,)))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 50)                250
#
#  dense_12 (Dense)            (None, 30)                1530
#
#  dense_13 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 함수형 API 스타일
from tensorflow.keras import Model
input_ = Input(shape=(4,))
layer1 = Dense(units=50, activation='relu')(input_)
layer2 = Dense(units=30, activation='relu')(layer1)
output = Dense(units=3, activation='softmax')(layer2)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 4)]               0
#
#  dense_14 (Dense)            (None, 50)                250
#
#  dense_15 (Dense)            (None, 30)                1530
#
#  dense_16 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4->160->3
# 기존의 model 방식
model = Sequential([
    Input(shape=(4,)),
    Dense(units=160, activation='relu'),
    Dense(units=3, activation='softmax')
])
# 함수형 API 방식
input_ = Input(shape=(4,))
layer  = Dense(units=160, activation='relu')(input_)
output = Dense(units=3,   activation='softmax')(layer)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 4)]               0
#
#  dense_19 (Dense)            (None, 160)               800
#
#  dense_20 (Dense)            (None, 3)                 483
#
# =================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4->160->3를 병렬처리 방식
from tensorflow.keras.layers import concatenate
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x      = concatenate([dense1, dense2, dense3])
output = Dense(units=3, activation='softmax')(x)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 4)]          0           []
#
#  dense_21 (Dense)               (None, 50)           250         ['input_8[0][0]']
#
#  dense_22 (Dense)               (None, 80)           400         ['input_8[0][0]']
#
#  dense_23 (Dense)               (None, 30)           150         ['input_8[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_21[0][0]',
#                                                                   'dense_22[0][0]',
#                                                                   'dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 3)            483         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 레지듀얼 블럭(Residual Block)
from tensorflow.keras.layers import add
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
layer1 = Dense(units=64, activation='relu')(dense1)
layer2 = Dense(units=50, activation='relu')(layer1)
dense2 = add([dense1, layer2])
output = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 4)]          0           []
#
#  dense_25 (Dense)               (None, 50)           250         ['input_9[0][0]']
#
#  dense_26 (Dense)               (None, 64)           3264        ['dense_25[0][0]']
#
#  dense_27 (Dense)               (None, 50)           3250        ['dense_26[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_25[0][0]',
#                                                                   'dense_27[0][0]']
#
#  dense_28 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 6,917
# Trainable params: 6,917
# Non-trainable params: 0
# __________________________________________________________________________________________________
